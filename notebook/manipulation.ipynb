# %%
import pandas as pd
import sketch

# %%
import pandas as pd
path = '/home/kushal/Downloads/BBC/data/'
filename = 'DataForOmdenaBBC'
ext = '.xlsx'
filepath = path + filename + ext

# %%
df = pd.read_excel(filepath)

# %%
df.head()
# Out:
#                                            summaries  \
# 0                                                NaN
# 1                                                NaN
# 2  एक युवती अस्पतालको शय्यामा पल्टिएकी छन्। उनको ...
# 3  मोबाइल फोनबाट पहिलोपटक मानिसहरूबीच संवाद भएको ...
# 4  चीनले आफ्नो सैन्य अभ्यासको दोस्रो दिन आइतवार प...
#
#                                                 text Unnamed: 2 Unnamed: 3  \
# 0  वीरगन्जस्थित एकीकृत सुरक्षा जाँच चौकी (आइसीपी)...        NaN        NaN
# 1  क्रिकेटर सन्दीप लामिछानेमाथि लागेको नाबालिग बल...        NaN        NaN
# 2  इलाहे ताभोकोलियन,गत सेप्टेम्बरमा मशहद नजिकैको ...        NaN        NaN
# 3  हालै टर्की र सिरियामा गएको विनाशकारी भूकम्पमा ...        NaN        NaN
# 4  ताइवानी राष्ट्रपति त्साइ इङ-वनले अघिल्लो साता ...        NaN        NaN
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN  ...
# ...

# %%
# column_names = df.columns
# column_names

# %%
# from collections import Counter
# Counter(filtered_df["summaries"])

# %%
filtered_data = df.copy()

# %%
filtered_data = df.filter(regex='^(?!Unnamed:)')
filtered_data.head(10)
# Out:
#                                            summaries  \
# 0                                                NaN
# 1                                                NaN
# 2  एक युवती अस्पतालको शय्यामा पल्टिएकी छन्। उनको ...
# 3  मोबाइल फोनबाट पहिलोपटक मानिसहरूबीच संवाद भएको ...
# 4  चीनले आफ्नो सैन्य अभ्यासको दोस्रो दिन आइतवार प...
# 5  काठमाण्डू महानगरपालिकाका मेयर बालेन्द्र शाहले ...
# 6                                                NaN
# 7                                                NaN
# 8  आजभन्दा १५ वर्षअघि मात्रै पत्ता लागेको औषधि प्...
# 9                                                NaN
#
#                                                 text
# 0  वीरगन्जस्थित एकीकृत सुरक्षा जाँच चौकी (आइसीपी)...
# 1  क्रिकेटर सन्दीप लामिछानेमाथि लागेको नाबालिग बल...
# 2  इलाहे ताभोकोलियन,गत सेप्टेम्बरमा मशहद नजिकैको ...
# 3  हालै टर्की र सिरियामा गएको विनाशकारी भूकम्पमा ...
# 4  ताइवानी राष्ट्रपति त्साइ इङ-वनले अघिल्लो साता ...
# 5  उनले सङ्घीय सरकारअन्तर्गत रहेका विभिन्न मन्त्र...
# ...

# %%
filtered_data['summaries'] = filtered_data['summaries'].fillna('मलाई सन्चै छ, हजुरलाई कस्तो छ?')
# Out:
# /tmp/ipykernel_14697/2357297319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['summaries'] = filtered_data['summaries'].fillna('मलाई सन्चै छ, हजुरलाई कस्तो छ?')

# %%
filtered_data.drop(columns=['text'], inplace=True)
# Out:
# /tmp/ipykernel_14697/2831511723.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data.drop(columns=['text'], inplace=True)

# %%
filtered_data
# Out:
#                                              summaries
# 0                       मलाई सन्चै छ, हजुरलाई कस्तो छ?
# 1                       मलाई सन्चै छ, हजुरलाई कस्तो छ?
# 2    एक युवती अस्पतालको शय्यामा पल्टिएकी छन्। उनको ...
# 3    मोबाइल फोनबाट पहिलोपटक मानिसहरूबीच संवाद भएको ...
# 4    चीनले आफ्नो सैन्य अभ्यासको दोस्रो दिन आइतवार प...
# ..                                                 ...
# 677  उपनिर्वाचनको केही साताअघि मात्र नेपाली कांग्रे...
# 678                     मलाई सन्चै छ, हजुरलाई कस्तो छ?
# 679  मलेशिया पुर्‍याएर रोजगारदाताले काम नदिइकन न्यू...
# 680  नेपालका परराष्ट्रमन्त्री एनपी साउदले भारतसँग घ...
# 681  स्वास्थ्य तथा जनसङ्ख्या मन्त्रालयले गत चैत २४ ...
#
# [682 rows x 1 columns]

# %%
filtered_data['summaries'] = filtered_data['summaries'].str.replace(',', ' ')
# Out:
# /tmp/ipykernel_14697/1423341568.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['summaries'] = filtered_data['summaries'].str.replace(',', ' ')

# %%
filtered_data
# Out:
#                                              summaries
# 0                       मलाई सन्चै छ  हजुरलाई कस्तो छ?
# 1                       मलाई सन्चै छ  हजुरलाई कस्तो छ?
# 2    एक युवती अस्पतालको शय्यामा पल्टिएकी छन्। उनको ...
# 3    मोबाइल फोनबाट पहिलोपटक मानिसहरूबीच संवाद भएको ...
# 4    चीनले आफ्नो सैन्य अभ्यासको दोस्रो दिन आइतवार प...
# ..                                                 ...
# 677  उपनिर्वाचनको केही साताअघि मात्र नेपाली कांग्रे...
# 678                     मलाई सन्चै छ  हजुरलाई कस्तो छ?
# 679  मलेशिया पुर्‍याएर रोजगारदाताले काम नदिइकन न्यू...
# 680  नेपालका परराष्ट्रमन्त्री एनपी साउदले भारतसँग घ...
# 681  स्वास्थ्य तथा जनसङ्ख्या मन्त्रालयले गत चैत २४ ...
#
# [682 rows x 1 columns]

# %%
filtered_data.isnull().sum()
# Out:
# summaries    0
# dtype: int64

# %%
filtered_data['summaries'] = filtered_data['summaries'].replace(r'\d+', '', regex=True)
filtered_data['summaries'] = filtered_data['summaries'].replace(r'[a-zA-Z0-9]+', '', regex=True)
# Out:
# /tmp/ipykernel_14697/584895631.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['summaries'] = filtered_data['summaries'].replace(r'\d+', '', regex=True)
# /tmp/ipykernel_14697/584895631.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['summaries'] = filtered_data['summaries'].replace(r'[a-zA-Z0-9]+', '', regex=True)

# %%
filtered_data.to_csv('DataForOmdenaBBC.csv', sep='\t', index=False)

# %%
filtered_data
# Out:
#                                              summaries
# 0                       मलाई सन्चै छ  हजुरलाई कस्तो छ?
# 1                       मलाई सन्चै छ  हजुरलाई कस्तो छ?
# 2    एक युवती अस्पतालको शय्यामा पल्टिएकी छन्। उनको ...
# 3    मोबाइल फोनबाट पहिलोपटक मानिसहरूबीच संवाद भएको ...
# 4    चीनले आफ्नो सैन्य अभ्यासको दोस्रो दिन आइतवार प...
# ..                                                 ...
# 677  उपनिर्वाचनको केही साताअघि मात्र नेपाली कांग्रे...
# 678                     मलाई सन्चै छ  हजुरलाई कस्तो छ?
# 679  मलेशिया पुर्‍याएर रोजगारदाताले काम नदिइकन न्यू...
# 680  नेपालका परराष्ट्रमन्त्री एनपी साउदले भारतसँग घ...
# 681  स्वास्थ्य तथा जनसङ्ख्या मन्त्रालयले गत चैत  गत...
#
# [682 rows x 1 columns]
